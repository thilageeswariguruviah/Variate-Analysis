# %%
#import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#data on boarding
from google.colab import files
df = files.upload()
# Out:
#      <input type="file" id="files-5f2e045e-8d13-4b1d-bce3-d3e2a7608031" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5f2e045e-8d13-4b1d-bce3-d3e2a7608031">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#raw data into data frame
df = pd.read_csv('01Exercise1.csv')

# %%
#copy of the data
data_copy = df.copy()

# %%
#EDA
df.shape
# Out:
# (614, 6)

# %%
df.head()
# Out:
#   gender married   ch  income  loanamt status
# 0   Male      No  1.0    5849      NaN      Y
# 1   Male     Yes  1.0    4583    128.0      N
# 2   Male     Yes  1.0    3000     66.0      Y
# 3   Male     Yes  1.0    2583    120.0      Y
# 4   Male      No  1.0    6000    141.0      Y

# %%
df.tail()
# Out:
#      gender married   ch  income  loanamt status
# 609  Female      No  1.0    2900     71.0      Y
# 610    Male     Yes  1.0    4106     40.0      Y
# 611    Male     Yes  1.0    8072    253.0      Y
# 612    Male     Yes  1.0    7583    187.0      Y
# 613  Female      No  0.0    4583    133.0      N

# %%
#data slicing
df.iloc[0:20]
# Out:
#     gender married   ch  income  loanamt status
# 0     Male      No  1.0    5849      NaN      Y
# 1     Male     Yes  1.0    4583    128.0      N
# 2     Male     Yes  1.0    3000     66.0      Y
# 3     Male     Yes  1.0    2583    120.0      Y
# 4     Male      No  1.0    6000    141.0      Y
# 5     Male     Yes  1.0    5417    267.0      Y
# 6     Male     Yes  1.0    2333     95.0      Y
# 7     Male     Yes  0.0    3036    158.0      N
# 8     Male     Yes  1.0    4006    168.0      Y
# 9     Male     Yes  1.0   12841    349.0      N
# 10    Male     Yes  1.0    3200     70.0      Y
# 11    Male     Yes  1.0    2500    109.0      Y
# 12    Male     Yes  1.0    3073    200.0      Y
# 13    Male      No  1.0    1853    114.0      N
# 14    Male     Yes  1.0    1299     17.0      Y
# 15    Male      No  1.0    4950    125.0      Y
# 16    Male      No  NaN    3596    100.0      Y
# 17  Female      No  0.0    3510     76.0      N
# 18    Male     Yes  1.0    4887    133.0      N
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   gender   601 non-null    object
#  1   married  611 non-null    object
#  2   ch       564 non-null    float64
#  3   income   614 non-null    int64
#  4   loanamt  592 non-null    float64
#  5   status   614 non-null    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 28.9+ KB

# %%
#data cleaning
df.isnull().sum()
# Out:
# gender     13
# married     3
# ch         50
# income      0
# loanamt    22
# status      0
# dtype: int64

# %%
#mini statistical report
df.describe()
# Out:
#                ch        income     loanamt
# count  564.000000    614.000000  592.000000
# mean     0.842199   5403.459283  146.412162
# std      0.364878   6109.041673   85.587325
# min      0.000000    150.000000    9.000000
# 25%      1.000000   2877.500000  100.000000
# 50%      1.000000   3812.500000  128.000000
# 75%      1.000000   5795.000000  168.000000
# max      1.000000  81000.000000  700.000000

# %% [markdown]
# **Univariate Plots**
#
# Univariate analysis explores each variable in a data set, separately.

# %%
sns.displot(df.income,bins=10,kde=False)
plt.show()

# %%
sns.boxplot(x = df['income'])
plt.show()

# %%
sns.countplot(x='income',data=df)
plt.show()

# %%
sns.displot(x='loanamt',data = df)
plt.show()

# %% [markdown]
# **Bivariate analysis**
#
#  Bivariate in Python refers to the analysis involving two variables. It uses statistical methods and visualizations to explore the relationship and interactions between these two variables in a dataset

# %%
sns.catplot(data = df, x = 'gender', y = 'income',kind = 'violin');
plt.show()

# %%
#Scatter plot
df.plot(x = 'income', y = 'loanamt', kind = 'scatter');
plt.show()

# %%
sns.jointplot(data = df, x = 'married', y = 'loanamt');
plt.show()

# %%
#seaborn Scatter plot
sns.regplot(data = df, x = 'gender', y = 'loanamt', fit_reg=False);
plt.show()

# %%
fig, ax = plt.subplots()
df.plot(ax=ax);
plt.show()

# %% [markdown]
# **Multivariate analysis**
#
#
# Multivariate analysis is based in observation and analysis of more than one statistical outcome variable at a time

# %%
sns.pairplot(df, hue = "status")
plt.show()

# %% [markdown]
# We don’t see any pattern in the pair plot. But, again this can be used to see how two continuous features behave for different classes

# %% [markdown]
# we looked at the definitions of bivariate,multivariate analysis. We also looked at some ways to perform such analysis in python. We used some plots to identify relations between variables
